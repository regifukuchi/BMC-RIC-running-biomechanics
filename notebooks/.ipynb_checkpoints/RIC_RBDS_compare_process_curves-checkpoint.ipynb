# %% [markdown]
# # Compare angles between centres
#
# Reginaldo K Fukuchi, Feb 2023, reginaldo.fukuchi@ufabc.edu.br
#
# This NB imports text files from both centres to compare the curves

# %%
# Prepare environment
import os, glob
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib notebook

# %% [markdown]
# ## University of Calgary Running Injury Clinic (RIC)

# %%
# Import data
dir_RIC = r'C:\Users\Reginaldo\Documents\data\CNPq\MCR_run'
fnames_RIC  = glob.glob(os.path.join(dir_RIC,'*.txt'))
fnames_RIC
# Out:
# ['C:\\Users\\Reginaldo\\Documents\\data\\CNPq\\MCR_run\\20130731T140334.txt',
#  'C:\\Users\\Reginaldo\\Documents\\data\\CNPq\\MCR_run\\20150223T121342.txt',
#  'C:\\Users\\Reginaldo\\Documents\\data\\CNPq\\MCR_run\\20150223T125146.txt',
#  'C:\\Users\\Reginaldo\\Documents\\data\\CNPq\\MCR_run\\20150224T101056.txt',
#  'C:\\Users\\Reginaldo\\Documents\\data\\CNPq\\MCR_run\\20150224T104510.txt',
#  'C:\\Users\\Reginaldo\\Documents\\data\\CNPq\\MCR_run\\20150303T103235.txt',
#  'C:\\Users\\Reginaldo\\Documents\\data\\CNPq\\MCR_run\\20150303T125747.txt',
#  'C:\\Users\\Reginaldo\\Documents\\data\\CNPq\\MCR_run\\20150305T115232.txt',
#  'C:\\Users\\Reginaldo\\Documents\\data\\CNPq\\MCR_run\\20150305T123016.txt',
#  'C:\\Users\\Reginaldo\\Documents\\data\\CNPq\\MCR_run\\20150306T112153.txt',
#  'C:\\Users\\Reginaldo\\Documents\\data\\CNPq\\MCR_run\\20150306T123841.txt',
#  'C:\\Users\\Reginaldo\\Documents\\data\\CNPq\\MCR_run\\20150307T105351.txt',
#  'C:\\Users\\Reginaldo\\Documents\\data\\CNPq\\MCR_run\\20150307T112120.txt',
#  'C:\\Users\\Reginaldo\\Documents\\data\\CNPq\\MCR_run\\20150307T114452.txt',
#  'C:\\Users\\Reginaldo\\Documents\\data\\CNPq\\MCR_run\\20150307T122935.txt',
#  'C:\\Users\\Reginaldo\\Documents\\data\\CNPq\\MCR_run\\20150309T111319.txt',
#  'C:\\Users\\Reginaldo\\Documents\\data\\CNPq\\MCR_run\\20150309T125032.txt',
#  'C:\\Users\\Reginaldo\\Documents\\data\\CNPq\\MCR_run\\20170615T124736.txt',
#  'C:\\Users\\Reginaldo\\Documents\\data\\CNPq\\MCR_run\\20170615T125556.txt',
#  'C:\\Users\\Reginaldo\\Documents\\data\\CNPq\\MCR_run\\20170618T111419.txt',
#  'C:\\Users\\Reginaldo\\Documents\\data\\CNPq\\MCR_run\\20170620T103940.txt',
#  'C:\\Users\\Reginaldo\\Documents\\data\\CNPq\\MCR_run\\20170627T114223.txt']

# %%
info_RIC = pd.read_csv(os.path.join(dir_RIC, 'metadata_table.csv'))
info_RIC.head()
# Out:
#    sub_id            session_type    session_date_time  sub_age gender  \
# 0     712  Baseline (first visit)  2015-02-24 10:10:56       40   Male
# 1     712  Baseline (first visit)  2015-02-24 10:10:56       40   Male
# 2     777  Baseline (first visit)  2015-03-09 10:12:47       40   Male
# 3     777  Baseline (first visit)  2015-03-09 10:12:47       40   Male
# 4     793                     NaN  2013-07-31 14:03:34       32   Male
#
#   clinician bmech_examiner  walk_run_speed             filename
# 0       NaN         RickyW         3.36325  20150224T101056.mat
# 1       NaN         RickyW         3.66880  20150224T104510.mat
# 2       NaN         RickyW         3.36309  20150309T125032.mat
# 3       NaN         RickyW         3.67017  20150309T111319.mat
# 4     Shari          Shari         3.36977  20130731T140334.mat

# %%
info_RIC[['sub_age','walk_run_speed']].describe()
# Out:
#          sub_age  walk_run_speed
# count  22.000000       22.000000
# mean   32.227273        3.472205
# std     5.511303        0.151388
# min    25.000000        3.346660
# 25%    26.000000        3.355317
# 50%    32.500000        3.371030
# 75%    36.000000        3.662268
# max    40.000000        3.682570

# %% [markdown]
# ## Biomechanics and Motor Control Lab UFABC
# ### Running Biomechanics Data Set (RBDS)

# %%
dir_RBDS= r'C:\Users\Reginaldo\Documents\data\CNPq\RBDS_v2\Figshare'
fnames_RBDS = glob.glob(os.path.join(dir_RBDS,'*processed.txt'))
fnames_RBDS
# Out:
# ['C:\\Users\\Reginaldo\\Documents\\data\\CNPq\\RBDS_v2\\Figshare\\RBDS001processed.txt',
#  'C:\\Users\\Reginaldo\\Documents\\data\\CNPq\\RBDS_v2\\Figshare\\RBDS002processed.txt',
#  'C:\\Users\\Reginaldo\\Documents\\data\\CNPq\\RBDS_v2\\Figshare\\RBDS003processed.txt',
#  'C:\\Users\\Reginaldo\\Documents\\data\\CNPq\\RBDS_v2\\Figshare\\RBDS004processed.txt',
#  'C:\\Users\\Reginaldo\\Documents\\data\\CNPq\\RBDS_v2\\Figshare\\RBDS005processed.txt',
#  'C:\\Users\\Reginaldo\\Documents\\data\\CNPq\\RBDS_v2\\Figshare\\RBDS006processed.txt',
#  'C:\\Users\\Reginaldo\\Documents\\data\\CNPq\\RBDS_v2\\Figshare\\RBDS007processed.txt',
#  'C:\\Users\\Reginaldo\\Documents\\data\\CNPq\\RBDS_v2\\Figshare\\RBDS008processed.txt',
#  'C:\\Users\\Reginaldo\\Documents\\data\\CNPq\\RBDS_v2\\Figshare\\RBDS009processed.txt',
#  'C:\\Users\\Reginaldo\\Documents\\data\\CNPq\\RBDS_v2\\Figshare\\RBDS010processed.txt',
#  'C:\\Users\\Reginaldo\\Documents\\data\\CNPq\\RBDS_v2\\Figshare\\RBDS011processed.txt',
#  'C:\\Users\\Reginaldo\\Documents\\data\\CNPq\\RBDS_v2\\Figshare\\RBDS012processed.txt',
#  'C:\\Users\\Reginaldo\\Documents\\data\\CNPq\\RBDS_v2\\Figshare\\RBDS013processed.txt',
#  'C:\\Users\\Reginaldo\\Documents\\data\\CNPq\\RBDS_v2\\Figshare\\RBDS014processed.txt',
#  'C:\\Users\\Reginaldo\\Documents\\data\\CNPq\\RBDS_v2\\Figshare\\RBDS015processed.txt',
#  'C:\\Users\\Reginaldo\\Documents\\data\\CNPq\\RBDS_v2\\Figshare\\RBDS016processed.txt',
#  'C:\\Users\\Reginaldo\\Documents\\data\\CNPq\\RBDS_v2\\Figshare\\RBDS017processed.txt',
#  'C:\\Users\\Reginaldo\\Documents\\data\\CNPq\\RBDS_v2\\Figshare\\RBDS018processed.txt',
#  'C:\\Users\\Reginaldo\\Documents\\data\\CNPq\\RBDS_v2\\Figshare\\RBDS019processed.txt',
#  'C:\\Users\\Reginaldo\\Documents\\data\\CNPq\\RBDS_v2\\Figshare\\RBDS020processed.txt',
#  'C:\\Users\\Reginaldo\\Documents\\data\\CNPq\\RBDS_v2\\Figshare\\RBDS021processed.txt',
#  'C:\\Users\\Reginaldo\\Documents\\data\\CNPq\\RBDS_v2\\Figshare\\RBDS022processed.txt',
#  'C:\\Users\\Reginaldo\\Documents\\data\\CNPq\\RBDS_v2\\Figshare\\RBDS023processed.txt',
#  'C:\\Users\\Reginaldo\\Documents\\data\\CNPq\\RBDS_v2\\Figshare\\RBDS024processed.txt',
#  'C:\\Users\\Reginaldo\\Documents\\data\\CNPq\\RBDS_v2\\Figshare\\RBDS025processed.txt',
#  'C:\\Users\\Reginaldo\\Documents\\data\\CNPq\\RBDS_v2\\Figshare\\RBDS026processed.txt',
#  'C:\\Users\\Reginaldo\\Documents\\data\\CNPq\\RBDS_v2\\Figshare\\RBDS027processed.txt',
#  'C:\\Users\\Reginaldo\\Documents\\data\\CNPq\\RBDS_v2\\Figshare\\RBDS028processed.txt']

# %%
info_RBDS = pd.read_csv(os.path.join(dir_RBDS, 'RBDSinfo.txt'), delimiter='\t')
info_RBDS.drop_duplicates(subset='Subject', inplace=True)
info_RBDS.head()
# Out:
#     Subject           FileName  Age  Height   Mass Gender Dominance  \
# 0         1  RBDS001static.txt   22   181.0  62.00      M         R
# 12        2  RBDS002static.txt   38   183.0  80.00      M         R
# 24        3  RBDS003static.txt   34   177.0  65.40      M         L
# 36        4  RBDS004static.txt   33   168.0  57.05      M         R
# 48        5  RBDS005static.txt   32   169.0  60.00      M         R
#
#           Level  Experience  SessionsPerWk  ...  LThomas  ROber  LOber  \
# 0   Competitive           4              3  ...       11     43     40
# 12  Competitive          60              3  ...       12     43     38
# 24  Competitive          54              5  ...       15     44     41
# 36        Elite         216              4  ...       11     34     32
# 48  Competitive          36              5  ...        4     33     29
#
#       RHIPABD  LHIPABD  RHIPEXT    LHIPEXT     RHIPER     LHIPER     RHIPIR
# 0   16.800000   21.575   16.575  21.675000   9.666667   7.250000  10.966667
# 12  23.000000   28.025   23.700  21.500000  10.650000   9.600000  18.466667
# 24  22.033333   24.300   23.325  19.050000  10.333333  10.733333  15.500000
# 36  18.300000   14.350   15.600  16.966667   9.100000   6.966667  12.066667
# 48  18.833333   25.300   20.325  19.900000  12.200000   7.375000  10.700000
#
# [5 rows x 50 columns]

# %%
info_RBDS[['Age','Height','Mass']].describe()
# Out:
#              Age      Height       Mass
# count  28.000000   28.000000  28.000000
# mean   34.750000  175.960714  69.637500
# std     6.686775    6.802578   7.741514
# min    22.000000  162.700000  56.850000
# 25%    30.750000  169.000000  64.312500
# 50%    34.500000  177.400000  69.950000
# 75%    38.250000  181.825000  76.037500
# max    51.000000  187.200000  82.150000

# %% [markdown]
# ### Import files
# #### RBDS

# %%
joints = ['hip','knee','ankle']
axes = ['X','Y','Z']

# %%
angs_RBDS = np.empty(shape=(101, len(joints)*len(axes), len(fnames_RBDS))) * np.NaN
for f, fname in enumerate(fnames_RBDS):
    df_rbds = pd.read_csv(fname, delimiter='\t', index_col='PercGcycle')
    for j, joint in enumerate(joints):
        for xyz, axis in enumerate(axes):
            angs_RBDS[:,3*j+xyz, f] = df_rbds['R'+joint+'Ang'+axis+'35'].values

# %% [markdown]
# #### RIC

# %%
angs_RIC = np.empty(shape=(101, len(joints)*len(axes), len(fnames_RIC))) * np.NaN
for f, fname in enumerate(fnames_RIC):
    dir_RIC = pd.read_csv(fname, delimiter='\t', index_col='Frame')
    for j, joint in enumerate(joints):
        for xyz, axis in enumerate(axes):
            angs_RIC[:,3*j+xyz, f] = dir_RIC[joint+'_'+axis].values

# %% [markdown]
# ## Plotting comparing between centres

# %%
# Flipping the angles to be consistent
angs_RIC[:,2,:] = -angs_RIC[:,2,:]
angs_RIC[:,8,:] = -angs_RIC[:,8,:]

# %%
fig, axs = plt.subplots(nrows=len(joints), ncols=2, figsize=(10, 6))
plt.subplots_adjust(hspace=0.5)
fig.suptitle("Joint Angles", fontsize=18, y=0.95)
for j, joint in enumerate(joints):
    axs[j,0].plot(dir_RIC.index.values, angs_RIC[:,3*j+2,:],'b')
    axs[j,0].set_ylabel(joint)
    axs[j,1].plot(df_rbds.index.values, angs_RBDS[:,3*j+2,:],'r')
axs[0,0].set_title('RIC')
axs[2,0].set_xlabel('% Gait cycle')
axs[0,1].set_title('RBDS')
axs[2,1].set_xlabel('% Gait cycle')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %% [markdown]
# ## Compare curves using SPDM Two-sample t test

# %%
import spm1d

# %%
# Hip angles
t_hip  = spm1d.stats.ttest2(angs_RIC[:,2,:].T, angs_RBDS[:,2,:].T, 
                            equal_var=False)
ti_hip = t_hip.inference(alpha=0.05, two_tailed=False, interp=True)
# Knee angles
t_knee  = spm1d.stats.ttest2(angs_RIC[:,5,:].T, angs_RBDS[:,5,:].T, 
                            equal_var=False)
ti_knee = t_knee.inference(alpha=0.05, two_tailed=False, interp=True)
# Ankle angles
t_ankle  = spm1d.stats.ttest2(angs_RIC[:,8,:].T, angs_RBDS[:,8,:].T, 
                            equal_var=False)
ti_ankle = t_ankle.inference(alpha=0.05, two_tailed=False, interp=True)

# %%
#(2) Plot:
plt.close('all')
### plot mean and SD:
plt.figure( figsize=(10, 3.5) )
ax     = plt.axes( (0.1, 0.15, 0.35, 0.8) )
spm1d.plot.plot_mean_sd(angs_RIC[:,2,:].T)
spm1d.plot.plot_mean_sd(angs_RBDS[:,2,:].T, linecolor='r', facecolor='r')
ax.axhline(y=0, color='k', linestyle=':')
ax.set_xlabel('Gait cycle (%)')
ax.set_ylabel('Hip Angle  (deg)')
### plot SPM results:
ax     = plt.axes((0.55,0.15,0.35,0.8))
ti_hip.plot()
ti_hip.plot_threshold_label(fontsize=8)
ti_hip.plot_p_values(size=10, offsets=[(0,0.3)])
ax.set_xlabel('Gait cycle (%)')
plt.show()
plt.savefig(os.path.join(dir_RBDS,'spdm_hip.png'))
# Out:
# C:\Users\Reginaldo\AppData\Local\Temp\ipykernel_8004\3490034941.py:2: MatplotlibDeprecationWarning: The close_event function was deprecated in Matplotlib 3.6 and will be removed two minor releases later. Use callbacks.process('close_event', CloseEvent(...)) instead.
#   plt.close('all')
# <img src="data:image/png;base64,..." width="1000">

# %%
#(2) Plot:
plt.close('all')
### plot mean and SD:
plt.figure( figsize=(10, 3.5) )
ax     = plt.axes( (0.1, 0.15, 0.35, 0.8) )
spm1d.plot.plot_mean_sd(angs_RIC[:,5,:].T)
spm1d.plot.plot_mean_sd(angs_RBDS[:,5,:].T, linecolor='r', facecolor='r')
ax.axhline(y=0, color='k', linestyle=':')
ax.set_xlabel('Gait cycle (%)')
ax.set_ylabel('Knee Angle  (deg)')
### plot SPM results:
ax     = plt.axes((0.55,0.15,0.35,0.8))
ti_knee.plot()
ti_knee.plot_threshold_label(fontsize=8)
ti_knee.plot_p_values(size=10, offsets=[(0,0.3)])
ax.set_xlabel('Gait cycle (%)')
plt.show()
plt.savefig(os.path.join(dir_RBDS,'spdm_knee.png'))
# Out:
# C:\Users\Reginaldo\AppData\Local\Temp\ipykernel_8004\297668294.py:2: MatplotlibDeprecationWarning: The close_event function was deprecated in Matplotlib 3.6 and will be removed two minor releases later. Use callbacks.process('close_event', CloseEvent(...)) instead.
#   plt.close('all')
# <img src="data:image/png;base64,..." width="1000">
# WARNING:  there are fewer offsets than clusters.  To set offsets for all clusters use the offset_all_clusters keyword.

# %%
#(2) Plot:
plt.close('all')
### plot mean and SD:
plt.figure( figsize=(10, 3.5) )
ax     = plt.axes( (0.1, 0.15, 0.35, 0.8) )
spm1d.plot.plot_mean_sd(angs_RIC[:,8,:].T)
spm1d.plot.plot_mean_sd(angs_RBDS[:,8,:].T, linecolor='r', facecolor='r')
ax.axhline(y=0, color='k', linestyle=':')
ax.set_xlabel('Gait cycle (%)')
ax.set_ylabel('Ankle Angle  (deg)')
### plot SPM results:
ax     = plt.axes((0.55,0.15,0.35,0.8))
ti_ankle.plot()
ti_ankle.plot_threshold_label(fontsize=8)
ti_ankle.plot_p_values(size=10, offsets=[(0,0.3)])
ax.set_xlabel('Gait cycle (%)')
plt.show()
plt.savefig(os.path.join(dir_RBDS,'spdm_ankle.png'))
# Out:
# C:\Users\Reginaldo\AppData\Local\Temp\ipykernel_8004\223350841.py:2: MatplotlibDeprecationWarning: The close_event function was deprecated in Matplotlib 3.6 and will be removed two minor releases later. Use callbacks.process('close_event', CloseEvent(...)) instead.
#   plt.close('all')
# <img src="data:image/png;base64,..." width="1000">
# WARNING:  there are fewer offsets than clusters.  To set offsets for all clusters use the offset_all_clusters keyword.

# %% [markdown]
# # Plot average at each centre

# %%
fig, axs = plt.subplots(nrows=len(joints), ncols=3, figsize=(10, 6))
plt.subplots_adjust(hspace=0.5)
fig.suptitle("Joint Angles", fontsize=18, y=0.95)
for j, joint in enumerate(joints):
    for xyz, axis in enumerate(axes):
        axs[j,xyz].plot(dir_RIC.index.values, 
                        np.mean(angs_RIC[:,3*j+xyz,:], axis=1),'b')
        axs[j,xyz].plot(df_rbds.index.values, 
                        np.mean(angs_RBDS[:,3*j+xyz,:], axis=1),'r')
        axs[j,0].set_ylabel(joint)
        axs[0,xyz].set_title(axis)
        axs[2,xyz].set_xlabel('% Gait cycle')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1000">
